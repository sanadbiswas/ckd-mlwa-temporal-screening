# %% [markdown]
# # CKD MLWA final v5 reproducibility launcher
#
# This launcher runs the repository's complete research notebook and then applies the final `WTPH2YR` survey-weight revision used in the submission-ready manuscript.
#
# - Development weighted analysis: `WTMEC2YR`
# - 2021–2023 temporal weighted analysis: `WTPH2YR`
# - Survey weights are evaluation-only and do not alter model fitting, calibration, or the frozen threshold.
#
# The final revised numerical outputs are also stored under `results/`.

# %%
# Run the complete research notebook first.
# %run CKD_MLWA_Research.ipynb

# %%
# Apply the final 2021–2023 WTPH2YR survey-weight revision.
# %run WTPH2YR_revision_patch.py

# %% [markdown]
# ## Expected revised weighted temporal values
#
# Weighted prevalence 0.1406; ROC-AUC 0.7938; PR-AUC 0.4378; Brier 0.0989; log loss 0.3309; accuracy 0.7201; precision 0.3019; sensitivity 0.7549; specificity 0.7144; F1 0.4313; ECE 0.0128.
